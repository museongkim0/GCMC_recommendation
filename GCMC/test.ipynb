# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

def format_pytorch_version(version):
  return version.split('+')[0]
  

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

# %%
def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# %%
CUDA
# Out:
# 'cu111'

# %%
CUDA_version
# Out:
# '11.1'

# %%
# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 7.9 MB 5.3 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 3.5 MB 5.3 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 2.3 MB 5.0 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 747 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 325 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 407 kB 30.3 MB/s
# ...
#      |████████████████████████████████| 45 kB 3.4 MB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.2-py3-none-any.whl size=535570 sha256=c39f50543da6e8e944778a6f3a3aac5fe5c946d2db2ba2260250ef96f7cc3770
#   Stored in directory: /root/.cache/pip/wheels/3f/08/13/2321517088bb2e95bfd0e45033bb9c923189e5b2078e0be4ef
# ...

# %%
! pip install comet-ml==3.0.2
! pip install pyyaml==5.4
# Out:
# ...
#      |████████████████████████████████| 170 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 409 kB 38.9 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34546 sha256=f2e364b3bc2309c1188be8823b70953f26e6134c5c0c07db18fb9fe5c7dbc366
#   Stored in directory: /root/.cache/pip/wheels/0d/c4/19/13d74440f2a571841db6b6e0a273694327498884dafb9cf978
# Successfully built configobj
# ...
#      |████████████████████████████████| 636 kB 5.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
pip freeze
# Out:
# absl-py==0.12.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# appdirs==1.4.4
# argcomplete==1.12.3
# argon2-cffi==21.1.0
# arviz==0.11.4
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# atari-py==0.2.9
# atomicwrites==1.4.0
# attrs==21.2.0
# audioread==2.1.9
# autograd==1.3
# Babel==2.9.1
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==4.1.0
# blis==0.4.1
# bokeh==2.3.3
# Bottleneck==1.3.2
# branca==0.4.2
# bs4==0.0.1
# CacheControl==0.12.10
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==1.0.0
# certifi==2021.10.8
# cffi==1.15.0
# cftime==1.5.1.1
# chardet==3.0.4
# charset-normalizer==2.0.8
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.9.5
# colorcet==2.0.6
# colorlover==0.3.0
# comet-git-pure==0.19.16
# comet-ml==3.0.2
# community==1.0.0b1
# configobj==5.0.6
# contextlib2==0.5.5
# convertdate==2.3.2
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cupy-cuda111==9.4.0
# cvxopt==1.2.7
# cvxpy==1.0.31
# ...

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/gcmc 수정
# Out:
# /content/drive/MyDrive/gcmc 수정

# %%
ls
# Out:
#  config.yml   dataset.py              layers.py   __pycache__/   train.py
#  data/       '코드 수정 확인.ipynb'   model.py    trainer.py     utils.py

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 1
# Out:
# Settings:
# {'feature_data': 'None', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 1, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: None
# x:  torch.Size([6513])
# Done!
# [ Epoch:    1/1000 | Loss: 2.353988 | RMSE: 3.123085 | Test RMSE: 2.933186 ]
# [ Epoch:    2/1000 | Loss: 4.124880 | RMSE: 1.825784 | Test RMSE: 2.969347 ]
# [ Epoch:    3/1000 | Loss: 4.336854 | RMSE: 2.227167 | Test RMSE: 3.017109 ]
# [ Epoch:    4/1000 | Loss: 2.640106 | RMSE: 1.828724 | Test RMSE: 3.055739 ]
# [ Epoch:    5/1000 | Loss: 2.326063 | RMSE: 2.585105 | Test RMSE: 3.067112 ]
# [ Epoch:    6/1000 | Loss: 2.380805 | RMSE: 3.182309 | Test RMSE: 3.040457 ]
# [ Epoch:    7/1000 | Loss: 2.193846 | RMSE: 1.853033 | Test RMSE: 3.035026 ]
# [ Epoch:    8/1000 | Loss: 2.276705 | RMSE: 1.833643 | Test RMSE: 3.042493 ]
# [ Epoch:    9/1000 | Loss: 2.049658 | RMSE: 1.917922 | Test RMSE: 3.052731 ]
# ...

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 9 -fd graph1
# Out:
# Settings:
# {'feature_data': 'graph1', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 9, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: graph1
# x:  torch.Size([6513, 9])
# Done!
# [ Epoch:    1/1000 | Loss: 2.369042 | RMSE: 3.034069 | Test RMSE: 2.797407 ]
# [ Epoch:    2/1000 | Loss: 9.928622 | RMSE: 1.832824 | Test RMSE: 3.005157 ]
# [ Epoch:    3/1000 | Loss: 3.234953 | RMSE: 2.046284 | Test RMSE: 2.972411 ]
# [ Epoch:    4/1000 | Loss: 4.795220 | RMSE: 2.234931 | Test RMSE: 3.033916 ]
# [ Epoch:    5/1000 | Loss: 2.752964 | RMSE: 2.925823 | Test RMSE: 2.864658 ]
# [ Epoch:    6/1000 | Loss: 4.569834 | RMSE: 1.874903 | Test RMSE: 2.944055 ]
# [ Epoch:    7/1000 | Loss: 3.035058 | RMSE: 2.152132 | Test RMSE: 3.045694 ]
# [ Epoch:    8/1000 | Loss: 2.413493 | RMSE: 2.990142 | Test RMSE: 3.026464 ]
# ...

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 9 -fd graph2
# Out:
# Settings:
# {'feature_data': 'graph2', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 9, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: graph2
# x:  torch.Size([6513, 9])
# Done!
# [ Epoch:    1/1000 | Loss: 2.280084 | RMSE: 2.937244 | Test RMSE: 2.379778 ]
# [ Epoch:    2/1000 | Loss: 8.944746 | RMSE: 2.654162 | Test RMSE: 2.336600 ]
# [ Epoch:    3/1000 | Loss: 3.205698 | RMSE: 2.499185 | Test RMSE: 4.536220 ]
# [ Epoch:    4/1000 | Loss: 3.725199 | RMSE: 3.999055 | Test RMSE: 3.391077 ]
# [ Epoch:    5/1000 | Loss: 2.767793 | RMSE: 2.832674 | Test RMSE: 2.355796 ]
# [ Epoch:    6/1000 | Loss: 3.467152 | RMSE: 2.557755 | Test RMSE: 2.409468 ]
# [ Epoch:    7/1000 | Loss: 2.166423 | RMSE: 2.040149 | Test RMSE: 3.183177 ]
# [ Epoch:    8/1000 | Loss: 2.270975 | RMSE: 2.743191 | Test RMSE: 3.651683 ]
# ...

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 9 -fd nn
# Out:
# Settings:
# {'feature_data': 'nn', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 9, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: nn
# x:  torch.Size([6513, 9])
# Done!
# [ Epoch:    1/1000 | Loss: 2.313174 | RMSE: 3.062367 | Test RMSE: 3.040491 ]
# [ Epoch:    2/1000 | Loss: 2.954725 | RMSE: 2.508100 | Test RMSE: 3.049824 ]
# [ Epoch:    3/1000 | Loss: 4.820488 | RMSE: 4.746059 | Test RMSE: 3.053715 ]
# [ Epoch:    4/1000 | Loss: 3.484992 | RMSE: 2.875945 | Test RMSE: 3.052133 ]
# [ Epoch:    5/1000 | Loss: 3.153039 | RMSE: 3.749303 | Test RMSE: 3.046852 ]
# [ Epoch:    6/1000 | Loss: 2.560878 | RMSE: 3.428923 | Test RMSE: 3.041776 ]
# [ Epoch:    7/1000 | Loss: 2.393931 | RMSE: 3.034634 | Test RMSE: 3.039714 ]
# [ Epoch:    8/1000 | Loss: 2.500689 | RMSE: 3.021549 | Test RMSE: 3.040383 ]
# [ Epoch:    9/1000 | Loss: 2.330059 | RMSE: 2.934906 | Test RMSE: 3.042178 ]
# ...

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 3 -fd pca
# Out:
# Settings:
# {'feature_data': 'pca', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 3, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: pca
# x:  torch.Size([6513, 3])
# Done!
# [ Epoch:    1/1000 | Loss: 2.340558 | RMSE: 3.067236 | Test RMSE: 3.058809 ]
# [ Epoch:    2/1000 | Loss: 4.888886 | RMSE: 4.296897 | Test RMSE: 3.054757 ]
# [ Epoch:    3/1000 | Loss: 2.746863 | RMSE: 3.495222 | Test RMSE: 3.133248 ]
# [ Epoch:    4/1000 | Loss: 3.269655 | RMSE: 3.619623 | Test RMSE: 3.059229 ]
# [ Epoch:    5/1000 | Loss: 3.495085 | RMSE: 3.137481 | Test RMSE: 3.029667 ]
# [ Epoch:    6/1000 | Loss: 2.461974 | RMSE: 2.778308 | Test RMSE: 3.076369 ]
# [ Epoch:    7/1000 | Loss: 2.552135 | RMSE: 3.387218 | Test RMSE: 3.100559 ]
# [ Epoch:    8/1000 | Loss: 2.570836 | RMSE: 3.373329 | Test RMSE: 3.070976 ]
# [ Epoch:    9/1000 | Loss: 2.335854 | RMSE: 3.109819 | Test RMSE: 3.047724 ]
# ...

# %%
rm -rf data

# %%
# !python train.py -e 1000 -lr 0.01 -nf 3 -fd vae
# Out:
# Settings:
# {'feature_data': 'vae', 'learning_rate': 0.01, 'epochs': 1000, 'hidden_size': [500, 75], 'accum': 'add', 'drop_prob': 0.7, 'num_basis': 2, 'num_features': 3, 'testing': False}
#
# ...
# Extracting data/book/raw/uc
# Processing...
# feature: vae
# x:  torch.Size([6513, 3])
# Done!
# [ Epoch:    1/1000 | Loss: 2.343913 | RMSE: 3.026220 | Test RMSE: 3.034932 ]
# [ Epoch:    2/1000 | Loss: 5.843618 | RMSE: 3.040522 | Test RMSE: 3.058658 ]
# [ Epoch:    3/1000 | Loss: 6.885173 | RMSE: 1.842041 | Test RMSE: 3.038404 ]
# [ Epoch:    4/1000 | Loss: 2.652656 | RMSE: 3.084732 | Test RMSE: 2.997098 ]
# [ Epoch:    5/1000 | Loss: 3.433723 | RMSE: 2.339862 | Test RMSE: 3.007302 ]
# [ Epoch:    6/1000 | Loss: 3.073405 | RMSE: 2.449612 | Test RMSE: 3.028428 ]
# [ Epoch:    7/1000 | Loss: 2.525042 | RMSE: 2.844753 | Test RMSE: 3.047375 ]
# [ Epoch:    8/1000 | Loss: 2.822778 | RMSE: 2.961735 | Test RMSE: 3.041989 ]
# [ Epoch:    9/1000 | Loss: 2.494584 | RMSE: 3.111529 | Test RMSE: 3.030986 ]
# ...
